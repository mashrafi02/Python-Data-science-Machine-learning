# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

df_csv = pd.read_csv('/content/test.csv')

# %%
df_csv
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# 2                  All industries  Dollars (millions)           H05
# 3                  All industries  Dollars (millions)           H07
# 4                  All industries  Dollars (millions)           H08
# ...                           ...                 ...           ...
# 41710  Food product manufacturing          Percentage           H37
# 41711  Food product manufacturing          Percentage           H38
# 41712  Food product manufacturing          Percentage           H39
# 41713  Food product manufacturing          Percentage           H40
# 41714  Food product manufacturing          Percentage           H41
#
#                                          Variable_name      Variable_category  \
# 0                                         Total income  Financial performance
# 1      Sales, government funding, grants and subsidies  Financial performance
# 2                    Interest, dividends and donations  Financial performance
# 3                                 Non-operating income  Financial performance
# 4                                    Total expenditure  Financial performance
# ...                                                ...                    ...
# 41710                                      Quick ratio       Financial ratios
# 41711              Margin on sales of goods for resale       Financial ratios
# 41712                                 Return on equity       Financial ratios
# 41713                           Return on total assets       Financial ratios
# 41714                            Liabilities structure       Financial ratios
#
#          Value                             Industry_code_ANZSIC06
# 0      757,504  ANZSIC06 divisions A-S (excluding classes K633...
# 1      674,890  ANZSIC06 divisions A-S (excluding classes K633...
# 2       49,593  ANZSIC06 divisions A-S (excluding classes K633...
# 3       33,020  ANZSIC06 divisions A-S (excluding classes K633...
# 4      654,404  ANZSIC06 divisions A-S (excluding classes K633...
# ...        ...                                                ...
# 41710       52  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41711       40  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41712       12  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41713        5  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41714       46  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [41715 rows x 10 columns]

# %%
df_excel = pd.read_excel('/content/sample.xls', sheet_name='Sheet1' )

# %%
df_excel
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
df_excel.shape
# Out:
# (9, 8)

# %%
# Create a DataFrame from a dictionary
data_dict = {
    'column1': [1, 2, 3, 4],
    'column2': ['A', 'B', 'C', 'D']
}

# %%
df_dict = pd.DataFrame(data_dict)

# %%
df_dict
# Out:
#    column1 column2
# 0        1       A
# 1        2       B
# 2        3       C
# 3        4       D

# %%
# Create a DataFrame from a list of tuples
data_list_of_tuples = [
    (1, 'A'),
    (2, 'B'),
    (3, 'C'),
    (4, 'D')
]

# %%
df_touples = pd.DataFrame(data_list_of_tuples, columns=['Column1', 'Column2'])

# %%
df_touples
# Out:
#    Column1 Column2
# 0        1       A
# 1        2       B
# 2        3       C
# 3        4       D

# %%
# Create a DataFrame from a list of dictionaries
data_list_of_dicts = [
    {'column1': 1, 'column2': 'A'},
    {'column1': 2, 'column2': 'B'},
    {'column1': 3, 'column2': 'C'},
    {'column1': 4, 'column2': 'D'}
]

# %%
df_dict = pd.DataFrame(data_list_of_dicts)

# %%
df_dict
# Out:
#    column1 column2
# 0        1       A
# 1        2       B
# 2        3       C
# 3        4       D

# %%
import pandas as pd

# Create a simple DataFrame
data = {
    'A': [10, 20, 30, 40, 50, 60],
    'B': [5.5, 6.5, 7.5, 8.5, 9.5, 10.5],
    'C': ['X', 'Y', 'Z', 'X', 'Y', 'Z']
}
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#     A     B  C
# 0  10   5.5  X
# 1  20   6.5  Y
# 2  30   7.5  Z
# 3  40   8.5  X
# 4  50   9.5  Y
# 5  60  10.5  Z

# %%
df.shape
# Out:
# (6, 3)

# %%
df.head()
# Out:
#     A    B  C
# 0  10  5.5  X
# 1  20  6.5  Y
# 2  30  7.5  Z
# 3  40  8.5  X
# 4  50  9.5  Y

# %%
df.head(3)
# Out:
#     A    B  C
# 0  10  5.5  X
# 1  20  6.5  Y
# 2  30  7.5  Z

# %%
df.tail(2)
# Out:
#     A     B  C
# 4  50   9.5  Y
# 5  60  10.5  Z

# %%
df
# Out:
#     A     B  C
# 0  10   5.5  X
# 1  20   6.5  Y
# 2  30   7.5  Z
# 3  40   8.5  X
# 4  50   9.5  Y
# 5  60  10.5  Z

# %%
(10+20+30+40+50+60)/6
# Out:
# 35.0

# %%
df.min()
# Out:
# A     10
# B    5.5
# C      X
# dtype: object

# %%
# Minimum value in each column
print(df.min(numeric_only=True))
# Out:
# A    10.0
# B     5.5
# dtype: float64

# %%
# Maximum value in each column
print(df.max(numeric_only=True))
# Out:
# A    60.0
# B    10.5
# dtype: float64

# %%
# Mean value of each column
print(df.mean(numeric_only=True))
# Out:
# A    35.0
# B     8.0
# dtype: float64

# %%
# Standard deviation of each column
print(df.std(numeric_only=True))
# Out:
# A    18.708287
# B     1.870829
# dtype: float64

# %%
# Summary statistics
print(df.describe())
# Out:
#                A          B
# count   6.000000   6.000000
# mean   35.000000   8.000000
# std    18.708287   1.870829
# min    10.000000   5.500000
# 25%    22.500000   6.750000
# 50%    35.000000   8.000000
# 75%    47.500000   9.250000
# max    60.000000  10.500000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       6 non-null      int64
#  1   B       6 non-null      float64
#  2   C       6 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 272.0+ bytes
# None

# %%
df
# Out:
#     A     B  C
# 0  10   5.5  X
# 1  20   6.5  Y
# 2  30   7.5  Z
# 3  40   8.5  X
# 4  50   9.5  Y
# 5  60  10.5  Z

# %%
df[2:4]
# Out:
#     A    B  C
# 2  30  7.5  Z
# 3  40  8.5  X

# %%
df[['A','B']]
# Out:
#     A     B
# 0  10   5.5
# 1  20   6.5
# 2  30   7.5
# 3  40   8.5
# 4  50   9.5
# 5  60  10.5

# %%
df
# Out:
#     A     B  C
# 0  10   5.5  X
# 1  20   6.5  Y
# 2  30   7.5  Z
# 3  40   8.5  X
# 4  50   9.5  Y
# 5  60  10.5  Z

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
# Selecting a specific cell using .loc
print(df.loc[2, 'B'])
# Out:
# 7.5

# %%
import pandas as pd
import numpy as np

# Create a DataFrame with missing data
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [np.nan, 2.5, 3.5, np.nan, 5.5],
    'C': ['a', 'b', np.nan, 'd', 'e']
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN    a
# 1  2.0  2.5    b
# 2  NaN  3.5  NaN
# 3  4.0  NaN    d
# 4  5.0  5.5    e

# %%
# Selecting a specific cell using .iloc
print(df.iloc[0, 0])
# Out:
# 1.0

# %%
fill_with_one=df.fillna(1)

# %%
fill_with_one
# Out:
#      A    B  C
# 0  1.0  1.0  a
# 1  2.0  2.5  b
# 2  1.0  3.5  1
# 3  4.0  1.0  d
# 4  5.0  5.5  e

# %%
df.fillna(df.mean(numeric_only=True))
# Out:
#      A         B    C
# 0  1.0  3.833333    a
# 1  2.0  2.500000    b
# 2  3.0  3.500000  NaN
# 3  4.0  3.833333    d
# 4  5.0  5.500000    e

# %%
df
# Out:
#      A    B    C
# 0  1.0  NaN    a
# 1  2.0  2.5    b
# 2  NaN  3.5  NaN
# 3  4.0  NaN    d
# 4  5.0  5.5    e

# %%
# Forward-fill NaN values
df.fillna(method='ffill')
# Out:
#      A    B  C
# 0  1.0  NaN  a
# 1  2.0  2.5  b
# 2  2.0  3.5  b
# 3  4.0  3.5  d
# 4  5.0  5.5  e

# %%
df.fillna(method='bfill')
# Out:
#      A    B  C
# 0  1.0  2.5  a
# 1  2.0  2.5  b
# 2  4.0  3.5  d
# 3  4.0  5.5  d
# 4  5.0  5.5  e

# %% [markdown]
#  Dropna

# %%
import pandas as pd
import numpy as np

#create a dataframe with missing value

data = {
    'A' : [ 1, 2, np.nan, 4, 5],
    'B' : [np.nan, 2.5, 3.5, np.nan, 5.5],
    'C' : ['a', 'b', np.nan, 'd', 'e']
}

df = pd.DataFrame(data)


df
# Out:
#      A    B    C
# 0  1.0  NaN    a
# 1  2.0  2.5    b
# 2  NaN  3.5  NaN
# 3  4.0  NaN    d
# 4  5.0  5.5    e

# %%
df_dropna_rows = df.dropna()

# %%
df_dropna_rows
# Out:
#      A    B  C
# 1  2.0  2.5  b
# 4  5.0  5.5  e

# %%
#drop columns with any NaN values
df_dropna_cols = df.dropna(axis = 1)

# %%
df_dropna_cols
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
import pandas as pd
import numpy as np

#create a dataframe with missing value

data = {
    'A' : [ 1, 2, np.nan, 4, 5],
    'B' : [np.nan, 2.5, 3.5, np.nan, 5.5],
    'C' : ['a', 'b', np.nan, 'd', 'e']
}

df = pd.DataFrame(data)

print(df)
# Out:
#      A    B    C
# 0  1.0  NaN    a
# 1  2.0  2.5    b
# 2  NaN  3.5  NaN
# 3  4.0  NaN    d
# 4  5.0  5.5    e

# %%
#drop rows where all are NAN

df_dropna_all_rows = df.dropna(how='all')

# %%
print("\nDrop rows where all values are NaN:\n", df_dropna_all_rows)
# Out:
# Drop rows where all values are NaN:
#       A    B    C
# 0  1.0  NaN    a
# 1  2.0  2.5    b
# 2  NaN  3.5  NaN
# 3  4.0  NaN    d
# 4  5.0  5.5    e

# %%
import pandas as pd
import numpy as np

# Create a DataFrame with missing data
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [np.nan, 2.5, 3.5, np.nan, 5.5],
    'C': ['a', 'b', np.nan, 'd', 'e']
}
df = pd.DataFrame(data)

# Display the original DataFrame
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#       A    B    C
# 0  1.0  NaN    a
# 1  2.0  2.5    b
# 2  NaN  3.5  NaN
# 3  4.0  NaN    d
# 4  5.0  5.5    e

# %%
#interpolate missing values using linear method

df_interpolated_linear = df.interpolate()

print("linear interpolate\n",df_interpolated_linear)
# Out:
# linear interpolate
#       A    B    C
# 0  1.0  NaN    a
# 1  2.0  2.5    b
# 2  3.0  3.5  NaN
# 3  4.0  4.5    d
# 4  5.0  5.5    e

# %%
import pandas as pd
import numpy as np

# Create a DataFrame with missing data
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [np.nan, 2.5, 3.5, np.nan, 5.5],
    'C': ['a', 'b', np.nan, 'd', 'e']
}
df = pd.DataFrame(data)

# Display the original DataFrame
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#       A    B    C
# 0  1.0  NaN    a
# 1  2.0  2.5    b
# 2  NaN  3.5  NaN
# 3  4.0  NaN    d
# 4  5.0  5.5    e

# %%
df_replace = df.replace(np.nan, "missing")
print("dataframe with replace nans:\n",df_replace)
# Out:
# dataframe with replace nans:
#           A        B        C
# 0      1.0  missing        a
# 1      2.0      2.5        b
# 2  missing      3.5  missing
# 3      4.0  missing        d
# 4      5.0      5.5        e

# %%
import pandas as pd
import numpy as np

# Create a DataFrame with special placeholder values
data = {
    'temperature': [25.0, 30.5, -999.9, 22.0, 28.0],
    'wind speed': [5, -999, 15, 10, -999],
    'event': ['Rain', 'Sunny', 'Missing', 'Cloudy', 'Sunny'],
    'description': ['Hot day', 'Very hot day', 'Cold day', 'Windy day', 'Rainy day'],
    'score': ['poor', 'average', 'good', 'exceptional', 'good']
}
df = pd.DataFrame(data)

# Display the original DataFrame
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#     temperature  wind speed    event   description        score
# 0         25.0           5     Rain       Hot day         poor
# 1         30.5        -999    Sunny  Very hot day      average
# 2       -999.9          15  Missing      Cold day         good
# 3         22.0          10   Cloudy     Windy day  exceptional
# 4         28.0        -999    Sunny     Rainy day         good

# %%
df_replace_single_value = df.replace(10, np.nan)
print("replace single value with nan",df_replace_single_value)
# Out:
# replace single value with nan    temperature  wind speed    event   description        score
# 0         25.0         5.0     Rain       Hot day         poor
# 1         30.5      -999.0    Sunny  Very hot day      average
# 2       -999.9        15.0  Missing      Cold day         good
# 3         22.0         NaN   Cloudy     Windy day  exceptional
# 4         28.0      -999.0    Sunny     Rainy day         good

# %%
#Replace based on column
df_replaced_columns = df.replace({'temperature':30.5, 'wind speed':10,'event':'Missing'}, np.nan)
print(df_replaced_columns)
# Out:
#    temperature  wind speed   event   description        score
# 0         25.0         5.0    Rain       Hot day         poor
# 1          NaN      -999.0   Sunny  Very hot day      average
# 2       -999.9        15.0     NaN      Cold day         good
# 3         22.0         NaN  Cloudy     Windy day  exceptional
# 4         28.0      -999.0   Sunny     Rainy day         good

# %%
import pandas as pd
import numpy as np

# Create a DataFrame with special placeholder values
data = {
    'temperature': [25.0, 30.5, -999.9, 22.0, 28.0],
    'wind speed': [5, -999, 15, 10, -999],
    'event': ['Rain', 'Sunny', 'no event', 'Cloudy', 'Sunny'],
    'description': ['Hot day', 'Very hot day', 'Cold day', 'Windy day', 'Rainy day'],
    'score': ['poor', 'average', 'good', 'exceptional', 'good']
}
df = pd.DataFrame(data)

# Display the original DataFrame
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#     temperature  wind speed     event   description        score
# 0         25.0           5      Rain       Hot day         poor
# 1         30.5        -999     Sunny  Very hot day      average
# 2       -999.9          15  no event      Cold day         good
# 3         22.0          10    Cloudy     Windy day  exceptional
# 4         28.0        -999     Sunny     Rainy day         good

# %%
#Replace value using mapping
df_replacing_mapping = df.replace({-999.9: np.nan, 'no event': 'Sunny','poor':'bad' })
print(df_replacing_mapping)
# Out:
#    temperature  wind speed   event   description        score
# 0         25.0           5    Rain       Hot day          bad
# 1         30.5        -999   Sunny  Very hot day      average
# 2          NaN          15   Sunny      Cold day         good
# 3         22.0          10  Cloudy     Windy day  exceptional
# 4         28.0        -999   Sunny     Rainy day         good

# %%
import pandas as pd
import numpy as np

# Create a DataFrame with special placeholder values
data = {
    'temperature': [25.0, 30.5, -999.9, 22.0, 28.0],
    'wind speed': [5, -999, 15, 10, -999],
    'event': ['Rain', 'Sunny', 'no event', 'Cloudy', 'Sunny'],
    'description': ['Hot day', 'Very hot day', 'Cold day', 'Windy day', 'Rainy day'],
    'score': ['poor', 'average', 'good', 'exceptional', 'good']
}
df = pd.DataFrame(data)

# Display the original DataFrame
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#     temperature  wind speed     event   description        score
# 0         25.0           5      Rain       Hot day         poor
# 1         30.5        -999     Sunny  Very hot day      average
# 2       -999.9          15  no event      Cold day         good
# 3         22.0          10    Cloudy     Windy day  exceptional
# 4         28.0        -999     Sunny     Rainy day         good

# %%
#Replace list of values using a replacement map

replace_map = {'poor':1, 'average':2, 'good':3,'exceptional':4}
df['score'] = df['score'].replace(replace_map)

print("\nDataFrame with List of Values Replaced:\n", df)
# Out:
# DataFrame with List of Values Replaced:
#     temperature  wind speed     event   description  score
# 0         25.0           5      Rain       Hot day      1
# 1         30.5        -999     Sunny  Very hot day      2
# 2       -999.9          15  no event      Cold day      3
# 3         22.0          10    Cloudy     Windy day      4
# 4         28.0        -999     Sunny     Rainy day      3

# %%
import pandas as pd

# Sample employee data
data = {
    'EmployeeID': [101, 102, 103, 104, 105],
    'Name': ['John', 'Emma', 'Michael', 'Sophia', 'William'],
    'Department': ['HR', 'Marketing', 'Finance', 'IT', 'Operations'],
    'Salary': [60000, 70000, 80000, 90000, 65000],
    'ExperienceYears': [5, 3, 7, 4, 6]
}

df = pd.DataFrame(data)

print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#     EmployeeID     Name  Department  Salary  ExperienceYears
# 0         101     John          HR   60000                5
# 1         102     Emma   Marketing   70000                3
# 2         103  Michael     Finance   80000                7
# 3         104   Sophia          IT   90000                4
# 4         105  William  Operations   65000                6

# %%
#Rename columns
df.rename(columns={'Salary' : 'Monthlysalary', 'ExperienceYears':'YearsOfExperience'}, inplace = True)
print("\nDataFrame after Column Renaming:\n", df)
# Out:
# DataFrame after Column Renaming:
#     EmployeeID     Name  Department  Monthlysalary  YearsOfExperience
# 0         101     John          HR          60000                  5
# 1         102     Emma   Marketing          70000                  3
# 2         103  Michael     Finance          80000                  7
# 3         104   Sophia          IT          90000                  4
# 4         105  William  Operations          65000                  6

# %%
# Adding a new column for annual salary
df['AnnualSalary'] = df['Monthlysalary'] * 12
print("\nDataFrame with Annual Salary Column:\n", df)
# Out:
# DataFrame with Annual Salary Column:
#     EmployeeID     Name  Department  Monthlysalary  YearsOfExperience  \
# 0         101     John          HR          60000                  5
# 1         102     Emma   Marketing          70000                  3
# 2         103  Michael     Finance          80000                  7
# 3         104   Sophia          IT          90000                  4
# 4         105  William  Operations          65000                  6
#
#    AnnualSalary
# 0        720000
# 1        840000
# 2        960000
# 3       1080000
# 4        780000

# %%
#Dropping 'EEmployeeID' from dataframe
df.drop(columns = ['EmployeeID'], inplace = True)
print("\nDataFrame after Dropping 'EmployeeID' Column:\n", df)
# Out:
# DataFrame after Dropping 'EmployeeID' Column:
#        Name  Department  Monthlysalary  YearsOfExperience  AnnualSalary
# 0     John          HR          60000                  5        720000
# 1     Emma   Marketing          70000                  3        840000
# 2  Michael     Finance          80000                  7        960000
# 3   Sophia          IT          90000                  4       1080000
# 4  William  Operations          65000                  6        780000

# %%
#Filtering data for employees with salary 75000
high_salary_employess = df[df['Monthlysalary'] > 75000]
print("\nHigh Salary Employees:\n", high_salary_employess)
# Out:
# High Salary Employees:
#        Name Department  Monthlysalary  YearsOfExperience  AnnualSalary
# 2  Michael    Finance          80000                  7        960000
# 3   Sophia         IT          90000                  4       1080000

# %%
import pandas as pd

# Sample employee data
data = {
    'EmployeeID': [101, 102, 103, 104, 105],
    'Name': ['John', 'Emma', 'Michael', 'Sophia', 'William'],
    'Department': ['HR', 'Marketing', 'Finance', 'IT', 'Operations'],
    'Salary': [60000, 70000, 80000, 90000, 65000],
    'ExperienceYears': [5, 3, 7, 4, 6]
}

df = pd.DataFrame(data)

print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#     EmployeeID     Name  Department  Salary  ExperienceYears
# 0         101     John          HR   60000                5
# 1         102     Emma   Marketing   70000                3
# 2         103  Michael     Finance   80000                7
# 3         104   Sophia          IT   90000                4
# 4         105  William  Operations   65000                6

# %%
#Sorting data by years of experience in descending order
sorted_df = df.sort_values(by='ExperienceYears', ascending = False)
print("\nSorted DataFrame by Years of Experience:\n", sorted_df)
# Out:
# Sorted DataFrame by Years of Experience:
#     EmployeeID     Name  Department  Salary  ExperienceYears
# 2         103  Michael     Finance   80000                7
# 4         105  William  Operations   65000                6
# 0         101     John          HR   60000                5
# 3         104   Sophia          IT   90000                4
# 1         102     Emma   Marketing   70000                3

# %%
df['Department'] = df['Department'].replace({'HR':'Human Resources', 'IT': 'Infrormation Technology'})
print("\nDataFrame with Replaced Department Names:\n", df)
# Out:
# DataFrame with Replaced Department Names:
#     EmployeeID     Name               Department  Salary  ExperienceYears
# 0         101     John          Human Resources   60000                5
# 1         102     Emma                Marketing   70000                3
# 2         103  Michael                  Finance   80000                7
# 3         104   Sophia  Infrormation Technology   90000                4
# 4         105  William               Operations   65000                6

# %%
#applying a functionb a salary a column to convert to hourly rate
df['HourlyRate'] = df['Salary'].apply(lambda x: x / (4*40)) #Assuming 4 weeks and 40 hours per week
print("\nDataFrame with Hourly Rate column:\n",df)
# Out:
# DataFrame with Hourly Rate column:
#     EmployeeID     Name               Department  Salary  ExperienceYears  \
# 0         101     John          Human Resources   60000                5
# 1         102     Emma                Marketing   70000                3
# 2         103  Michael                  Finance   80000                7
# 3         104   Sophia  Infrormation Technology   90000                4
# 4         105  William               Operations   65000                6
#
#    HourlyRate
# 0      375.00
# 1      437.50
# 2      500.00
# 3      562.50
# 4      406.25

# %%
import pandas as pd

# Sample employee data
data = {
    'EmployeeID': [101, 102, 103, 104, 105,106],
    'Name': ['John', 'Emma', 'Michael', 'Sophia','mahi', 'William'],
    'Department': ['HR', 'Marketing','Marketing', 'Finance', 'IT', 'Operations'],
    'Salary': [60000, 70000, 80000,85000, 90000, 65000],
    'ExperienceYears': [5, 3, 7, 4,6,6]
}

df = pd.DataFrame(data)

print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#     EmployeeID     Name  Department  Salary  ExperienceYears
# 0         101     John          HR   60000                5
# 1         102     Emma   Marketing   70000                3
# 2         103  Michael   Marketing   80000                7
# 3         104   Sophia     Finance   85000                4
# 4         105     mahi          IT   90000                6
# 5         106  William  Operations   65000                6

# %%
#Grouping by department and calculating average salary

avg_salary_by_department = df.groupby('Department')['Salary'].mean()
print("\nAverage salary by Deparment:\n",avg_salary_by_department)
# Out:
# Average salary by Deparment:
#  Department
# Finance       85000.0
# HR            60000.0
# IT            90000.0
# Marketing     75000.0
# Operations    65000.0
# Name: Salary, dtype: float64

# %%
#Introducing missing values

df.loc[2, 'Salary'] = None

print(df)

#filling missing valus with median salary

median_salary  = df['Salary'].median()
df['Salary'].fillna(median_salary, inplace = True)
print("\nDataFrame after Filling Missing Values:\n", df)
# Out:
#    EmployeeID     Name  Department   Salary  ExperienceYears
# 0         101     John          HR  60000.0                5
# 1         102     Emma   Marketing  70000.0                3
# 2         103  Michael   Marketing      NaN                7
# 3         104   Sophia     Finance  85000.0                4
# 4         105     mahi          IT  90000.0                6
# 5         106  William  Operations  65000.0                6
#
# DataFrame after Filling Missing Values:
#     EmployeeID     Name  Department   Salary  ExperienceYears
# 0         101     John          HR  60000.0                5
# 1         102     Emma   Marketing  70000.0                3
# 2         103  Michael   Marketing  70000.0                7
# 3         104   Sophia     Finance  85000.0                4
# 4         105     mahi          IT  90000.0                6
# 5         106  William  Operations  65000.0                6

# %%
import pandas as pd

# Create first DataFrame
data1 = {
    'A': [1, 2, 3],
    'B': ['a', 'b', 'c']
}
df1 = pd.DataFrame(data1)

# Create second DataFrame
data2 = {
    'A': [4, 5, 6],
    'B': ['d', 'e', 'f']
}
df2 = pd.DataFrame(data2)

# Display the DataFrames
print("DataFrame 1:\n", df1)
print("\nDataFrame 2:\n", df2)
# Out:
# DataFrame 1:
#     A  B
# 0  1  a
# 1  2  b
# 2  3  c
#
# DataFrame 2:
#     A  B
# 0  4  d
# 1  5  e
# 2  6  f

# %%
#simple concat along rows
df_concat = pd.concat([df1, df2])
print("\nSimple Concatenate:\n", df_concat)
# Out:
# Simple Concatenate:
#     A  B
# 0  1  a
# 1  2  b
# 2  3  c
# 0  4  d
# 1  5  e
# 2  6  f

# %%
import pandas as pd

# Create first DataFrame
data1 = {
    'A': [1, 2, 3],
    'B': ['a', 'b', 'c']
}
df1 = pd.DataFrame(data1)

# Create second DataFrame
data2 = {
    'A': [4, 5, 6],
    'B': ['d', 'e', 'f']
}
df2 = pd.DataFrame(data2)

# Display the DataFrames
print("DataFrame 1:\n", df1)
print("\nDataFrame 2:\n", df2)
# Out:
# DataFrame 1:
#     A  B
# 0  1  a
# 1  2  b
# 2  3  c
#
# DataFrame 2:
#     A  B
# 0  4  d
# 1  5  e
# 2  6  f

# %%
#concatenate and ignore original index
df_concat_ignore_index = pd.concat([df1, df2], ignore_index = True)
print("\nConcatenate Ignoring Original Index:\n", df_concat_ignore_index)
# Out:
# Concatenate Ignoring Original Index:
#     A  B
# 0  1  a
# 1  2  b
# 2  3  c
# 3  4  d
# 4  5  e
# 5  6  f

# %%
#Concatenate along columns

df_concat_columns = pd.concat([df1,df2], axis=1)
print("\nConcatenate Along columns:\n", df_concat_columns)
# Out:
# Concatenate Along columns:
#     A  B  A  B
# 0  1  a  4  d
# 1  2  b  5  e
# 2  3  c  6  f

# %%
#concatenate and set new index
df_concat_new_index = pd.concat([df1, df2]).reset_index(drop = True)
df_concat_new_index.index = ['row1','row2','row3','row4','row5','row6']

# %%
df_concat_new_index
# Out:
#       A  B
# row1  1  a
# row2  2  b
# row3  3  c
# row4  4  d
# row5  5  e
# row6  6  f

# %% [markdown]
# Merge

# %%
import pandas as pd

df1 = pd.DataFrame({'key':['A','B','C'], 'value1':[1,2,3]})
df2 = pd.DataFrame({'key':['B','C','D'], 'value1':[4,5,6]})

# %%
result = pd.merge(df1, df2, on='key', how='inner')
print(result)
# Out:
#   key  value1_x  value1_y
# 0   B         2         4
# 1   C         3         5

# %%
result = pd.merge(df1, df2, on='key', how='outer')
print(result)
# Out:
#   key  value1_x  value1_y
# 0   A       1.0       NaN
# 1   B       2.0       4.0
# 2   C       3.0       5.0
# 3   D       NaN       6.0

# %%
import pandas as pd

df1 = pd.DataFrame({'key':['A','B','C'], 'value1':[1,2,3]})
df2 = pd.DataFrame({'key':['B','C','D'], 'value1':[4,5,6]})

# %%
result = pd.merge(df1, df2, on='key', how='left')
print(result)
# Out:
#   key  value1_x  value1_y
# 0   A         1       NaN
# 1   B         2       4.0
# 2   C         3       5.0

# %%
result = pd.merge(df1, df2, on='key', how='right')
print(result)
# Out:
#   key  value1_x  value1_y
# 0   B       2.0         4
# 1   C       3.0         5
# 2   D       NaN         6

# %% [markdown]
# ### Shifting

# %% [markdown]
# shit up/down

# %%
df = pd.DataFrame({'value': [1, 2, 3, 4,5]})

# %%
df
# Out:
#    value
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5

# %%
df['shifted'] = df['value'].shift(1)

# %%
df
# Out:
#    value  shifted
# 0      1      NaN
# 1      2      1.0
# 2      3      2.0
# 3      4      3.0
# 4      5      4.0

# %% [markdown]
# Shift will fill

# %%
#shift up by 1 period

df['shift_reverse'] = df['value'].shift(-1)
df
# Out:
#    value  shifted  shift_reverse
# 0      1      NaN            2.0
# 1      2      1.0            3.0
# 2      3      2.0            4.0
# 3      4      3.0            5.0
# 4      5      4.0            NaN

# %%
df['shifted_value'] = df['value'].shift(1, fill_value = 0)
df
# Out:
#    value  shifted  shift_reverse  shifted_value
# 0      1      NaN            2.0              0
# 1      2      1.0            3.0              1
# 2      3      2.0            4.0              2
# 3      4      3.0            5.0              3
# 4      5      4.0            NaN              4

# %% [markdown]
# ### Group by

# %%
import pandas as pd

# Sample data
data = {
    'City': ['Dhaka', 'Chittagong', 'Khulna', 'Rajshahi', 'Sylhet',
             'Dhaka', 'Chittagong', 'Khulna', 'Rajshahi', 'Sylhet'],
    'Population': [8906039, 2683447, 663342, 763952, 531663,
                   8906039, 2683447, 663342, 763952, 531663],
    'Area': [306.38, 168.07, 59.57, 96.68, 26.50,
             306.38, 168.07, 59.57, 96.68, 26.50],
    'Temperature': [30, 29, 28, 32, 31,
                    33, 34, 35, 29, 30]
}

df = pd.DataFrame(data)

# Display the DataFrame
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#           City  Population    Area  Temperature
# 0       Dhaka     8906039  306.38           30
# 1  Chittagong     2683447  168.07           29
# 2      Khulna      663342   59.57           28
# 3    Rajshahi      763952   96.68           32
# 4      Sylhet      531663   26.50           31
# 5       Dhaka     8906039  306.38           33
# 6  Chittagong     2683447  168.07           34
# 7      Khulna      663342   59.57           35
# 8    Rajshahi      763952   96.68           29
# 9      Sylhet      531663   26.50           30

# %%
#group by city and calculate mean  Population

# %%
mean_population = df.groupby('City')['Population'].mean()
print("\nMean Population by City:\n", mean_population)
# Out:
# Mean Population by City:
#  City
# Chittagong    2683447.0
# Dhaka         8906039.0
# Khulna         663342.0
# Rajshahi       763952.0
# Sylhet         531663.0
# Name: Population, dtype: float64

# %%
#group by city and calculate mean of areas
mean_areas = df.groupby('City')['Area'].sum()
print("\nSum of Areas by City:\n",mean_areas)
# Out:
# Sum of Areas by City:
#  City
# Chittagong    336.14
# Dhaka         612.76
# Khulna        119.14
# Rajshahi      193.36
# Sylhet         53.00
# Name: Area, dtype: float64

# %%
mean_temperature = df.groupby('City')['Temperature'].mean()
print("\nMean temperature by City:\n", mean_temperature)
# Out:
# Mean temperature by City:
#  City
# Chittagong    31.5
# Dhaka         31.5
# Khulna        31.5
# Rajshahi      30.5
# Sylhet        30.5
# Name: Temperature, dtype: float64

# %%
# Group by 'City' and aggregate multiple functions
agg_functions = df.groupby('City').agg({
    'Population': 'mean',
    'Area': 'sum',
    'Temperature': ['mean', 'max']
})

print("\nAggregated Data by City:\n", agg_functions)
# Out:
# Aggregated Data by City:
#             Population    Area Temperature
#                  mean     sum        mean max
# City
# Chittagong  2683447.0  336.14        31.5  34
# Dhaka       8906039.0  612.76        31.5  33
# Khulna       663342.0  119.14        31.5  35
# Rajshahi     763952.0  193.36        30.5  32
# Sylhet       531663.0   53.00        30.5  31

# %%
# Sample data with 'Year'
data_with_year = {
    'City': ['Dhaka', 'Chittagong', 'Khulna', 'Rajshahi', 'Sylhet',
             'Dhaka', 'Chittagong', 'Khulna', 'Rajshahi', 'Sylhet'],
    'Year': [2023, 2023, 2023, 2023, 2023,
             2024, 2024, 2024, 2024, 2024],
    'Population': [8906039, 2683447, 663342, 763952, 531663,
                   8906039, 2683447, 663342, 763952, 531663],
    'Area': [306.38, 168.07, 59.57, 96.68, 26.50,
             306.38, 168.07, 59.57, 96.68, 26.50],
    'Temperature': [30, 29, 28, 32, 31,
                    33, 34, 35, 29, 30]
}

df_with_year = pd.DataFrame(data_with_year)

# Display the DataFrame with 'Year'
print("\nDataFrame with Year:\n", df_with_year)
# Out:
# DataFrame with Year:
#           City  Year  Population    Area  Temperature
# 0       Dhaka  2023     8906039  306.38           30
# 1  Chittagong  2023     2683447  168.07           29
# 2      Khulna  2023      663342   59.57           28
# 3    Rajshahi  2023      763952   96.68           32
# 4      Sylhet  2023      531663   26.50           31
# 5       Dhaka  2024     8906039  306.38           33
# 6  Chittagong  2024     2683447  168.07           34
# 7      Khulna  2024      663342   59.57           35
# 8    Rajshahi  2024      763952   96.68           29
# 9      Sylhet  2024      531663   26.50           30

# %%
#Group by city and year and calculate the mean temp

mean_temp_by_city_year = df_with_year.groupby(['City', 'Year'])['Temperature'].mean()
print(mean_temp_by_city_year)
# Out:
# City        Year
# Chittagong  2023    29.0
#             2024    34.0
# Dhaka       2023    30.0
#             2024    33.0
# Khulna      2023    28.0
#             2024    35.0
# Rajshahi    2023    32.0
#             2024    29.0
# Sylhet      2023    31.0
#             2024    30.0
# Name: Temperature, dtype: float64
