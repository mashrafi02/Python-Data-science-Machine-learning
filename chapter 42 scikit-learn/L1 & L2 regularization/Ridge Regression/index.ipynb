# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"E:\Gentle Hero\python_course\chapter 42 scikit-learn\datasets\archive\Marvel_Analysis.csv")
df.head()
# Out:
#   MCU_Phase                          Film_Title US_Release_Date  \
# 0   Phase I                            Iron Man     May 2, 2008
# 1   Phase I                 The Incredible Hulk    Jun 13, 2008
# 2   Phase I                          Iron Man 2     May 7, 2010
# 3   Phase I                                Thor     May 6, 2011
# 4   Phase I  Captain America: The First Avenger    Jul 22, 2011
#
#     Director_Names                                 Screenwriter_Names  \
# 0      Jon Favreau  Mark Fergus & Hawk Ostby and Art Marcum & Matt...
# 1  Louis Leterrier                                           Zak Penn
# 2      Jon Favreau                                     Justin Theroux
# 3  Kenneth Branagh   Ashley Edward Miller & Zack Stentz and Don Payne
# 4     Joe Johnston               Christopher Markus & Stephen McFeely
#
#                               Producer_Names  Budget_Million_Dollars  \
# 0                   Avi Arad and Kevin Feige                   140.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   MCU_Phase                                     40 non-null     object
#  1   Film_Title                                    40 non-null     object
#  2   US_Release_Date                               40 non-null     object
#  3   Director_Names                                40 non-null     object
#  4   Screenwriter_Names                            39 non-null     object
#  5   Producer_Names                                37 non-null     object
#  6   Budget_Million_Dollars                        33 non-null     float64
#  7   Opening_Weekend_WW_Million_Dollars            33 non-null     float64
#  8   Box_Office_US_CAN_Million_Dollars             33 non-null     float64
# ...

# %%
df.describe()
# Out:
#        Budget_Million_Dollars  Opening_Weekend_WW_Million_Dollars  \
# count               33.000000                           33.000000
# mean               216.545455                          254.484848
# std                 76.913137                          238.091254
# min                130.000000                           46.000000
# 25%                170.000000                           76.000000
# 50%                200.000000                          162.000000
# 75%                250.000000                          371.000000
# max                444.000000                         1224.000000
#
#        Box_Office_US_CAN_Million_Dollars  \
# count                          33.000000
# mean                          356.030303
# std                           192.268934
# min                            84.000000
# 25%                           214.000000
# 50%                           334.000000
# 75%                           411.000000
# ...

# %%
df.shape
# Out:
# (40, 16)

# %%
df.columns
# Out:
# Index(['MCU_Phase', 'Film_Title', 'US_Release_Date', 'Director_Names',
#        'Screenwriter_Names', 'Producer_Names', 'Budget_Million_Dollars',
#        'Opening_Weekend_WW_Million_Dollars',
#        'Box_Office_US_CAN_Million_Dollars',
#        'Box_Office_Other_Territories_Million_Dollars',
#        'Box_Office_WW_Million_Dollars', 'IMDb_Rating', 'Metacritic_Score',
#        'Tomatometer_Score', 'Audience_Score', 'Average_Score'],
#       dtype='object')

# %%
df.drop(['MCU_Phase', 'Film_Title', 'US_Release_Date', 'Director_Names',
       'Screenwriter_Names', 'Producer_Names', 'Budget_Million_Dollars',
       'Opening_Weekend_WW_Million_Dollars',
       'Box_Office_US_CAN_Million_Dollars',
       'Box_Office_Other_Territories_Million_Dollars',
       'Box_Office_WW_Million_Dollars',], axis=1, inplace=True)

df.head()
# Out:
#    IMDb_Rating  Metacritic_Score  Tomatometer_Score  Audience_Score  \
# 0          7.9              79.0               94.0            91.0
# 1          6.6              61.0               67.0            69.0
# 2          6.9              57.0               72.0            71.0
# 3          7.0              57.0               77.0            76.0
# 4          6.9              66.0               80.0            75.0
#
#    Average_Score
# 0            8.6
# 1            6.6
# 2            6.7
# 3            7.0
# 4            7.3

# %%
df.isna().sum()
# Out:
# IMDb_Rating          7
# Metacritic_Score     7
# Tomatometer_Score    7
# Audience_Score       7
# Average_Score        7
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# IMDb_Rating          0
# Metacritic_Score     0
# Tomatometer_Score    0
# Audience_Score       0
# Average_Score        0
# dtype: int64

# %%
np.isinf(df).sum()
# Out:
# IMDb_Rating          0
# Metacritic_Score     0
# Tomatometer_Score    0
# Audience_Score       0
# Average_Score        0
# dtype: int64

# %%
df
# Out:
#     IMDb_Rating  Metacritic_Score  Tomatometer_Score  Audience_Score  \
# 0           7.9              79.0               94.0            91.0
# 1           6.6              61.0               67.0            69.0
# 2           6.9              57.0               72.0            71.0
# 3           7.0              57.0               77.0            76.0
# 4           6.9              66.0               80.0            75.0
# 5           8.0              69.0               91.0            91.0
# 6           7.1              62.0               79.0            78.0
# 7           6.8              54.0               67.0            75.0
# 8           7.7              70.0               90.0            92.0
# 9           8.0              76.0               92.0            92.0
# 10          7.3              66.0               76.0            82.0
# 11          7.2              64.0               83.0            85.0
# 12          7.8              75.0               90.0            89.0
# ...

# %%
df.columns
# Out:
# Index(['IMDb_Rating', 'Metacritic_Score', 'Tomatometer_Score',
#        'Audience_Score', 'Average_Score'],
#       dtype='object')

# %%
X = df[['IMDb_Rating', 'Metacritic_Score', 'Tomatometer_Score',
       'Audience_Score']]
Y = df["Average_Score"]


X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2, random_state=42)
Y_test
# Out:
# 31    8.0
# 15    8.2
# 26    8.6
# 17    8.4
# 8     8.2
# 9     8.5
# 19    7.7
# Name: Average_Score, dtype: float64

# %%
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)


model = Ridge(alpha=1.0)
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

Y_pred
# Out:
# array([7.96349059, 8.15321828, 8.58435412, 8.45296513, 8.2178912 ,
#        8.50917517, 7.66153567])
